# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [ 'the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'T am a good developer',
        'understand the meaning of words',
        'your videos are good',]

# %%
voc_size = 10000

# %%
one_hot = [one_hot(words, voc_size)for words in sent]
one_hot
# Out:
# [[2207, 4470, 1863, 3557],
#  [2207, 4470, 1863, 1315],
#  [2207, 2393, 1863, 6453],
#  [3430, 971, 819, 8040, 115],
#  [5274, 2207, 8515, 1863, 1221],
#  [1921, 7677, 5823, 8040]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
set_length = 8
embedded_docs = pad_sequences(one_hot, padding='pre', maxlen=set_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 2207 4470 1863 3557]
#  [   0    0    0    0 2207 4470 1863 1315]
#  [   0    0    0    0 2207 2393 1863 6453]
#  [   0    0    0 3430  971  819 8040  115]
#  [   0    0    0 5274 2207 8515 1863 1221]
#  [   0    0    0    0 1921 7677 5823 8040]]

# %%
dim=10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim))
model.compile('adam', 'mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# array([[[-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.03009704,  0.01786492,  0.04058559, -0.01220758,
#           0.03806191, -0.00416075, -0.008954  ,  0.03089837,
#           0.02636217, -0.00695015],
#         [-0.04103786,  0.00271319,  0.04335029,  0.04702853,
#           0.01980156,  0.00193522,  0.00720651,  0.03643299,
#           0.0148665 , -0.03907413],
#         [ 0.04028196, -0.04743532,  0.02059067, -0.01874417,
#          -0.02214301, -0.02616758,  0.0266444 , -0.01155967,
#          -0.04204654, -0.01379317],
#         [-0.00808318,  0.00103294,  0.03854377,  0.03916233,
#           0.01714832, -0.00805839,  0.01542975,  0.03562725,
#          -0.00221757,  0.03412176]],
#
#        [[-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.03009704,  0.01786492,  0.04058559, -0.01220758,
#           0.03806191, -0.00416075, -0.008954  ,  0.03089837,
#           0.02636217, -0.00695015],
#         [-0.04103786,  0.00271319,  0.04335029,  0.04702853,
#           0.01980156,  0.00193522,  0.00720651,  0.03643299,
#           0.0148665 , -0.03907413],
#         [ 0.04028196, -0.04743532,  0.02059067, -0.01874417,
#          -0.02214301, -0.02616758,  0.0266444 , -0.01155967,
#          -0.04204654, -0.01379317],
#         [ 0.04825035, -0.03317294,  0.03881397,  0.03912817,
#           0.03926579,  0.0083256 , -0.00799947,  0.04519569,
#          -0.03922982, -0.01117178]],
#
#        [[-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.03009704,  0.01786492,  0.04058559, -0.01220758,
#           0.03806191, -0.00416075, -0.008954  ,  0.03089837,
#           0.02636217, -0.00695015],
#         [-0.01731415,  0.03480763,  0.0310797 ,  0.03203464,
#          -0.01569711, -0.02872105,  0.0037473 ,  0.02858056,
#          -0.02189146, -0.03161594],
#         [ 0.04028196, -0.04743532,  0.02059067, -0.01874417,
#          -0.02214301, -0.02616758,  0.0266444 , -0.01155967,
#          -0.04204654, -0.01379317],
#         [ 0.04388238,  0.03687295,  0.00958566, -0.04312127,
#           0.02794125, -0.04332406, -0.04800376,  0.01632685,
#           0.01986069, -0.02660204]],
#
#        [[-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01303226,  0.03563196, -0.00183938, -0.02585429,
#          -0.03246951,  0.0061376 , -0.01682748, -0.00610096,
#           0.01934556,  0.03988368],
#         [-0.04685061,  0.01159921, -0.03086405,  0.0474491 ,
#          -0.0297449 , -0.01367463, -0.03006644,  0.03439936,
#          -0.01392664,  0.03170428],
#         [ 0.03890273,  0.03692148, -0.04801219,  0.03535287,
#           0.01408608, -0.03749695,  0.03657824, -0.00402622,
#           0.00704218,  0.01245391],
#         [-0.0444494 ,  0.01058938,  0.00036133,  0.01184934,
#           0.03713789,  0.00971142,  0.04496148, -0.00777124,
#          -0.01763265, -0.00882963],
#         [ 0.00987033, -0.03296505,  0.02766224,  0.04538927,
#          -0.00937415, -0.02336501,  0.02642567,  0.0111515 ,
#          -0.04026707,  0.04926106]],
#
#        [[-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [ 0.00577153,  0.01833105,  0.04329617, -0.02075936,
#          -0.04235512,  0.03553169, -0.02186762,  0.01443383,
#           0.01513555, -0.01998919],
#         [-0.03009704,  0.01786492,  0.04058559, -0.01220758,
#           0.03806191, -0.00416075, -0.008954  ,  0.03089837,
#           0.02636217, -0.00695015],
#         [ 0.01361162, -0.02702737,  0.0030934 , -0.03118157,
#          -0.02674279,  0.03724765,  0.01045144,  0.0230971 ,
#           0.01352546,  0.01676908],
#         [ 0.04028196, -0.04743532,  0.02059067, -0.01874417,
#          -0.02214301, -0.02616758,  0.0266444 , -0.01155967,
#          -0.04204654, -0.01379317],
#         [-0.02872897, -0.00344907, -0.03640618, -0.02280864,
#           0.02841015, -0.03400445, -0.02114549, -0.00632019,
#          -0.02719811,  0.02740283]],
#
#        [[-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [-0.01258949, -0.01895065,  0.0196307 ,  0.04098357,
#          -0.00023166, -0.0324543 ,  0.01730577, -0.02185068,
#           0.00380685, -0.0279319 ],
#         [ 0.0443563 ,  0.01258732,  0.03112147,  0.01786177,
#           0.00549693,  0.01869173, -0.00277194, -0.04731009,
#          -0.02965464,  0.00823148],
#         [ 0.04786475, -0.03671304, -0.0324832 , -0.04402405,
#          -0.00273623, -0.04438034, -0.03649223,  0.04485456,
#           0.0229744 ,  0.02509889],
#         [ 0.04054521, -0.03627658, -0.0062355 ,  0.00143465,
#           0.01798871,  0.03309898, -0.00124296,  0.04022962,
#           0.01584605,  0.02588395],
#         [-0.0444494 ,  0.01058938,  0.00036133,  0.01184934,
#           0.03713789,  0.00971142,  0.04496148, -0.00777124,
#          -0.01763265, -0.00882963]]], dtype=float32)
